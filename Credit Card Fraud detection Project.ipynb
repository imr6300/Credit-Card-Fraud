# %%
import pandas as pd

# %%
df = pd.read_csv("Credit Card Capstone Project.csv")

# %%
pd.options.display.max_columns = None

# %% [markdown]
# # 1. Collect the time series data from the CSV file linked here.

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA) - Show the Data quality check, treat the missing values, outliers etc if any.

# %%
df.shape
# Out:
# (284807, 31)

# %%
print("Number of Rows",df.shape[0])
print("Number of Columns",df.shape[1])
# Out:
# Number of Rows 284807
# Number of Columns 31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759061e-12 -8.251130e-13 -9.654937e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649999e-13  4.248366e-13 -3.054600e-13  8.777971e-14 -1.179749e-12
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
df['Amount']=sc.fit_transform(pd.DataFrame(df['Amount']))

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Visualize outliers using boxplot
sns.boxplot(x=df['Amount'])
plt.show()

# %%
# Remove outliers (example using IQR)
Q1 = df['Amount'].quantile(0.25)
Q3 = df['Amount'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['Amount'] >= (Q1 - 1.5 * IQR)) & (df['Amount'] <= (Q3 + 1.5 * IQR))]

# %%
# Visualize data distribution
#Histogram
sns.histplot(df['Amount'])
plt.show()

# %%
# Density plot
sns.kdeplot(df['Amount'])
plt.show()

# %%
# Correlation analysis
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# # 3. Get the correct datatype for date.

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
# 5  0.260314 -0.568671 -0.371407  1.341262  0.359894 -0.358091 -0.137134
#
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'], errors='coerce')

# %%
print(df['Time'].isnull().sum())
# Out:
# 0

# %%
df.head()
# Out:
#                            Time        V1        V2        V3        V4  \
# 0 1970-01-01 00:00:00.000000000 -1.359807 -0.072781  2.536347  1.378155
# 1 1970-01-01 00:00:00.000000000  1.191857  0.266151  0.166480  0.448154
# 3 1970-01-01 00:00:00.000000001 -0.966272 -0.185226  1.792993 -0.863291
# 4 1970-01-01 00:00:00.000000002 -1.158233  0.877737  1.548718  0.403034
# 5 1970-01-01 00:00:00.000000002 -0.425966  0.960523  1.141109 -0.168252
#
#          V5        V6        V7        V8        V9       V10       V11  \
# 0 -0.338321  0.462388  0.239599  0.098698  0.363787  0.090794 -0.551600
# 1  0.060018 -0.082361 -0.078803  0.085102 -0.255425 -0.166974  1.612727
# 3 -0.010309  1.247203  0.237609  0.377436 -1.387024 -0.054952 -0.226487
# 4 -0.407193  0.095921  0.592941 -0.270533  0.817739  0.753074 -0.822843
# 5  0.420987 -0.029728  0.476201  0.260314 -0.568671 -0.371407  1.341262
#
#         V12       V13       V14       V15       V16       V17       V18  \
# ...

# %%
df = df.drop(['Time'],axis=1)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
# 5  0.260314 -0.568671 -0.371407  1.341262  0.359894 -0.358091 -0.137134
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %% [markdown]
# # 4. Balancing the data.

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    252502
# 1       401
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (252903, 30)

# %%
df.duplicated().any()
# Out:
# True

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (243920, 30)

# %%
252903-243920
# Out:
# 8983

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    243534
# 1       386
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Class', data=df)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# # 5. Feature Engineering and feature selection.

# %%
from imblearn.over_sampling import SMOTE
X_res,y_res = SMOTE().fit_resample(X, y)

# %%
from sklearn.feature_selection import RFE

# %%
# oversampling
X = df.drop('Class',axis=1)
y = df['Class']

# %%
X.shape
# Out:
# (243920, 29)

# %%
y.shape
# Out:
# (243920,)

# %%
y_res.value_counts()
# Out:
# Class
# 0    243534
# 1    243534
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_res,y_res,test_size=0.20,random_state=42)

# %%
# Logistic Regression
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9502535569835958

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9794604537093807

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.91965130145154

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9486140860602719

# %% [markdown]
# # 6. Train/Test Split - Apply a sampling distribution to find the best split.

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
# Logistic Regression.
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # 7. Choose the metrics for the model evaluation.

# %%
y_pred1 = log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.999221056083962

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9090909090909091

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.6024096385542169

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.7246376811594203

# %%
#undersampling.
normal = df[df['Class']==0]
fraud = df[df['Class']==1]

# %%
normal.shape
# Out:
# (243534, 30)

# %%
fraud.shape
# Out:
# (386, 30)

# %%
normal_sample = normal.sample(n=386)

# %%
normal_sample.shape
# Out:
# (386, 30)

# %%
new_df = pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0    386
# 1    386
# Name: count, dtype: int64

# %%
new_df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.033832  1.464458 -0.256392  2.293146  2.545133  0.489745  1.028480
# 1 -2.599059 -1.940926  1.949304  3.268409  3.450130 -1.692805 -1.553333
# 2 -7.532682  6.067426 -2.722817 -3.017215 -1.736247 -0.210791 -1.066194
# 3 -0.957219  0.468930  0.842984 -3.352997 -0.092953 -0.388927  0.309281
# 4  2.025956 -0.219774 -1.096391  0.280350 -0.193828 -0.973136  0.081565
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.730933 -2.287979  1.212694 -0.626932 -1.295945 -1.921426  1.157561
# 1  0.538439 -1.461963  1.090603  0.265099 -0.072367 -0.639510  0.476061
# 2  2.108813  4.228086  6.621303  0.386689  0.808963 -0.245781 -0.583369
# 3 -0.806938  1.768645 -1.786818 -1.129691  0.752538  0.538574 -0.537326
# 4 -0.298823  1.244264 -0.364851 -0.929253  0.901318  0.317861  0.011554
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
X = new_df.drop('Class',axis=1)
y = new_df['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# # 8. Model Selection, Training, Predicting and Assessment.

# %%
# Decision Tree Classifier.
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9354838709677419

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9459459459459459

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9210526315789473

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9333333333333332

# %%
# Random Forest Classifier.
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9548387096774194

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9859154929577465

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9210526315789473

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9523809523809524

# %% [markdown]
# # 9. Hyperparameter Tuning/Model Improvement.

# %%
# Oversampling
# Decision Tree Classifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.998347260147412

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.997720692416682

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9989719972038323

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.998345952720959

# %%
# Oversampling
# Random Forest Classifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9998562834910794

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.999712242045548

# %%
recall_score(y_test,y_pred3)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.999856100318635

# %%
final_df = pd.DataFrame({'Models':['LR','DT','RF'],"ACC":[accuracy_score(y_test,y_pred1)*100,
                                               accuracy_score(y_test,y_pred2)*100,
                                               accuracy_score(y_test,y_pred3)*100
                                              ]})

# %%
final_df
# Out:
#   Models        ACC
# 0     LR  95.025356
# 1     DT  99.834726
# 2     RF  99.985628

# %%
final_df = pd.DataFrame({
    'Models': ['LR', 'DT', 'RF'],
    'ACC': [95.025356, 99.834726, 99.985628]})

# %%
sns.barplot(x='Models', y='ACC', data=final_df)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %% [markdown]
# # 10. Model deployment plan.

# %%
# Save the Model
rf1 = RandomForestClassifier()
rf1.fit(X_res,y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf1,"credit_card_model")
# Out:
# ['credit_card_model']

# %%
model = joblib.load("credit_card_model")

# %% [markdown]
# # Conclusion
# By following this deployment plan, the credit card fraud detection model can be effectively integrated into a production environment, providing timely and accurate predictions while ensuring scalability, reliability, and maintainability.
